# %%
import pandas as pd

data = pd.read_csv("C:\\Users\\Nabeel Jawwad\\Downloads\\tested.csv")

# Display the first few rows of the DataFrame to verify that the data was loaded correctly
print(data.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# View the first few rows of the dataset
print("First few rows of the dataset:")
print(data.head())
print()

# Check the data types and missing values
print("Data types and missing values:")
print(data.info())
print()

# Generate summary statistics for numerical columns
print("Summary statistics for numerical columns:")
print(data.describe())
# Out:
# First few rows of the dataset:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S
#
# Data types and missing values:
# ...

# %%
# Identify missing values
missing_values = data.isnull()

# Count missing values in each column
missing_counts = missing_values.sum()

# Display columns with missing values and their respective counts
print("Columns with missing values:")
print(missing_counts[missing_counts > 0])
print()

# Handle missing values (example: fill missing values with mean)
# Replace 'column_name' with the actual column name where you want to fill missing values
# Replace 'mean' with 'median', 'mode', or any other appropriate value for imputation
data['Age'].fillna(data['Age'].mean(), inplace=True)
# Out:
# Columns with missing values:
# Age       86
# Fare       1
# Cabin    327
# dtype: int64

# %%
# Check the data types of the columns
print(data.dtypes)
# Out:
# PassengerId             int64
# Survived                int64
# Pclass                  int64
# Name                   object
# Sex                    object
# Age            datetime64[ns]
# SibSp                   int64
# Parch                   int64
# Ticket                 object
# Fare                  float64
# Cabin                  object
# Embarked               object
# dtype: object

# %%
# Convert 'Age' column to numeric (assuming it contains numerical data)
data['Age'] = pd.to_numeric(data['Age'], errors='coerce')

# Perform multiplication between 'Age' and 'Fare' columns
data['new_feature'] = data['Age'] * data['Fare']

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Summary statistics
print(data.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
# Distribution of a categorical variable(1 indicates survived and 0 indicates fatality)
sns.countplot(x='Survived', data=data)
plt.title('Distribution of Survival')
plt.show()

# %%
# Example: Distribution of Age
sns.histplot(data['Age'].dropna(), kde=True, bins=20)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Example: Scatter plot between Age and Fare
sns.scatterplot(x='Age', y='Fare', data=data)
plt.title('Relationship between Age and Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
# Example: Correlation matrix
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\Nabeel Jawwad\AppData\Local\Temp\ipykernel_18684\4102702137.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %%
# 1. Age Distribution by Gender and Passenger Class
plt.figure(figsize=(12, 6))
sns.boxplot(x='Pclass', y='Age', hue='Sex', data=data)
plt.title('Age Distribution by Gender and Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Age')
plt.show()

# %%
# 2. Survival Analysis by Age Group
age_bins = [0, 18, 35, 50, 100]
age_labels = ['Children', 'Young Adults', 'Adults', 'Seniors']
data['AgeGroup'] = pd.cut(data['Age'], bins=age_bins, labels=age_labels)

plt.figure(figsize=(8, 6))
sns.barplot(x='AgeGroup', y='Survived', data=data, ci=None)
plt.title('Survival Rate by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Survival Rate')
plt.show()
# Out:
# C:\Users\Nabeel Jawwad\AppData\Local\Temp\ipykernel_18684\1574164984.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='AgeGroup', y='Survived', data=data, ci=None)

# %%
# 3. Family Size Analysis
data['FamilySize'] = data['SibSp'] + data['Parch']

plt.figure(figsize=(8, 6))
sns.barplot(x='FamilySize', y='Survived', data=data, ci=None)
plt.title('Survival Rate by Family Size')
plt.xlabel('Family Size')
plt.ylabel('Survival Rate')
plt.show()
# Out:
# C:\Users\Nabeel Jawwad\AppData\Local\Temp\ipykernel_18684\2299797488.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='FamilySize', y='Survived', data=data, ci=None)

# %%
# 4. Fare Distribution by Passenger Class
plt.figure(figsize=(10, 6))
sns.boxplot(x='Pclass', y='Fare', data=data)
plt.title('Fare Distribution by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Fare')
plt.show()

# %%
# 5. Embarkation Point Analysis
plt.figure(figsize=(8, 6))
sns.barplot(x='Embarked', y='Survived', data=data, ci=None)
plt.title('Survival Rate by Embarkation Point')
plt.xlabel('Embarkation Point')
plt.ylabel('Survival Rate')
plt.show()
# Out:
# C:\Users\Nabeel Jawwad\AppData\Local\Temp\ipykernel_18684\4252204027.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Embarked', y='Survived', data=data, ci=None)

# %%
# 6. Name Analysis
data['Title'] = data['Name'].str.extract(' ([A-Za-z]+)\.')
plt.figure(figsize=(10, 6))
sns.barplot(x='Title', y='Survived', data=data, ci=None)
plt.title('Survival Rate by Title')
plt.xlabel('Title')
plt.ylabel('Survival Rate')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Nabeel Jawwad\AppData\Local\Temp\ipykernel_18684\2317133317.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Title', y='Survived', data=data, ci=None)

# %%
# 7. Cabin Analysis
data['HasCabin'] = data['Cabin'].notna()
plt.figure(figsize=(6, 6))
sns.barplot(x='HasCabin', y='Survived', data=data, ci=None)
plt.title('Survival Rate by Cabin Availability')
plt.xlabel('Has Cabin')
plt.ylabel('Survival Rate')
plt.xticks([0, 1], ['No', 'Yes'])
plt.show()
# Out:
# C:\Users\Nabeel Jawwad\AppData\Local\Temp\ipykernel_18684\583788146.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='HasCabin', y='Survived', data=data, ci=None)
